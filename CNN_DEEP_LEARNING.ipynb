# %%
# !pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-0ffd7756-47a4-43d1-8b94-88c71efc6757" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ffd7756-47a4-43d1-8b94-88c71efc6757">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"bqdesyhardianti","key":"68da920cfea76c5740d10af0b382c10c"}'}

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Downloading chest-xray-pneumonia.zip to /content
#  99% 2.27G/2.29G [01:23<00:01, 22.0MB/s]
# 100% 2.29G/2.29G [01:23<00:00, 29.4MB/s]

# %%
! mkdir train
! unzip chest-xray-pneumonia.zip -d tr
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: tr/chest_xray/train/NORMAL/IM-0435-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0435-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0437-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0437-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0437-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0438-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0439-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0439-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0439-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0440-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0441-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0442-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0444-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0445-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0446-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0447-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0448-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0449-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0450-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0451-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0452-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0453-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0453-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0455-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0456-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0457-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0458-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0459-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0460-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0461-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0463-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0464-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0465-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0466-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0467-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0467-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0467-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0469-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0471-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0472-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0473-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0474-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0475-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0476-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0477-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0478-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0479-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0480-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0481-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0482-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0483-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0484-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0485-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0486-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0487-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0488-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0489-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0490-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0491-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0491-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0491-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0492-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0493-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0494-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0495-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0496-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0497-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0497-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0497-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0499-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0499-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0499-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0500-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0501-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0501-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0501-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0502-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0503-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0504-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0505-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0505-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0505-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0506-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0507-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0508-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0509-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0509-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0509-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0510-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0511-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0511-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0511-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0512-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0513-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0514-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0515-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0516-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0517-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0517-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0519-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0519-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0519-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0520-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0521-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0522-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0523-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0523-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0523-0001-0003.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0523-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0524-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0525-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0525-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0525-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0526-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0527-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0528-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0529-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0530-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0531-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0531-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0532-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0533-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0533-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0533-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0534-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0535-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0536-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0537-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0538-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0539-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0539-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0539-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0540-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0541-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0542-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0543-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0543-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0544-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0545-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0545-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0545-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0546-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0547-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0548-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0549-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0549-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0549-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0551-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0551-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0551-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0552-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0553-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0553-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0553-0001-0003.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0553-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0554-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0555-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0555-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0555-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0556-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0557-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0559-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0560-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0561-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0562-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0563-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0564-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0565-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0566-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0568-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0569-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0570-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0571-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0574-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0575-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0577-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0578-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0579-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0580-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0581-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0582-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0583-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0584-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0586-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0588-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0590-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0591-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0592-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0593-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0595-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0596-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0598-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0599-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0600-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0601-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0602-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0604-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0605-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0606-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0607-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0608-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0608-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0608-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0609-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0612-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0612-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0612-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0613-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0614-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0615-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0616-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0617-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0618-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0618-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0618-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0619-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0620-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0620-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0620-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0621-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0622-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0622-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0622-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0623-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0624-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0624-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0625-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0626-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0626-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0627-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0628-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0629-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0629-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0629-0001-0003.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0629-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0630-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0631-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0631-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0631-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0632-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0633-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0634-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0635-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0636-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0637-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0640-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0640-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0640-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0641-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0642-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0643-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0644-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0644-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0644-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0645-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0646-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0647-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0648-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0649-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0650-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0650-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0650-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0651-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0652-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0652-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0654-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0655-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0656-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0656-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0656-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0657-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0658-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0659-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0660-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0660-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0660-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0661-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0662-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0663-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0664-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0665-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0666-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0666-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0666-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0667-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0668-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0669-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0670-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0671-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0672-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0673-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0674-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0675-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0676-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0677-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0678-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0679-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0680-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0681-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0682-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0683-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0684-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0685-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0686-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0687-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0688-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0689-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0691-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0692-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0693-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0694-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0695-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0696-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0697-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0698-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0700-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0701-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0702-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0703-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0704-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0705-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0706-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0707-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0709-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0710-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0711-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0712-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0713-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0714-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0715-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0716-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0717-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0718-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0719-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0721-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0722-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0724-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0727-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0728-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0729-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0730-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0732-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0733-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0734-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0735-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0736-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0737-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0738-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0739-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0740-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0741-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0742-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0746-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0747-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0748-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0750-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0751-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0752-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0753-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0754-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0755-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0757-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0761-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0764-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/IM-0766-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0383-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0384-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0385-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0386-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0388-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0389-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0390-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0391-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0392-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0393-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0394-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0396-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0397-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0399-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0401-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0402-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0403-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0404-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0406-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0407-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0408-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0409-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0410-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0412-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0413-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0414-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0415-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0417-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0418-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0419-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0421-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0423-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0424-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0425-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0427-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0428-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0429-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0433-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0435-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0437-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0439-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0440-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0441-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0443-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0445-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0447-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0448-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0449-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0450-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0451-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0452-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0453-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0454-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0455-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0456-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0458-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0460-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0462-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0463-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0464-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0465-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0466-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0468-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0472-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0473-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0474-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0475-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0476-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0478-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0479-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0480-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0481-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0482-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0485-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0486-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0487-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0488-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0489-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0490-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0491-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0493-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0496-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0497-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0499-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0500-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0501-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0502-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0503-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0506-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0507-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0508-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0509-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0511-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0512-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0513-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0515-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0516-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0517-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0518-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0520-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0521-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0522-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0523-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0525-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0526-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0528-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0529-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0530-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0531-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0533-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0535-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0535-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0536-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0537-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0539-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0540-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0541-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0543-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0545-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0547-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0550-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0551-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0552-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0553-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0554-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0557-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0558-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0559-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0561-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0563-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0564-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0566-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0567-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0568-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0569-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0571-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0572-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0573-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0575-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0576-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0577-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0578-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0579-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0580-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0582-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0583-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0585-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0588-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0589-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0592-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0594-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0595-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0596-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0599-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0600-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0601-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0602-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0603-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0604-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0609-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0611-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0616-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0617-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0618-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0619-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0620-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0621-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0622-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0623-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0626-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0627-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0629-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0630-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0633-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0634-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0635-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0636-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0637-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0640-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0641-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0642-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0643-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0645-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0647-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0648-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0649-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0650-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0651-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0651-0004.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0652-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0653-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0654-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0655-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0657-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0659-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0660-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0661-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0662-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0663-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0664-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0665-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0666-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0667-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0668-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0669-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0671-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0672-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0673-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0675-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0678-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0680-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0682-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0683-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0684-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0686-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0687-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0689-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0690-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0692-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0693-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0694-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0695-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0696-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0698-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0699-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0700-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0702-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0705-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0707-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0718-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0719-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0723-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0725-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0727-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0730-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0736-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0741-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0744-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0746-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0749-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0753-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0757-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0765-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0771-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0772-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0774-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0775-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0776-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0777-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0780-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0781-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0790-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0793-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0796-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0797-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0798-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0799-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0803-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0804-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0806-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0807-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0808-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0809-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0810-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0811-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0812-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0814-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0815-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0816-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0818-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0818-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0819-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0820-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0821-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0822-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0824-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0825-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0826-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0827-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0828-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0829-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0830-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0831-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0833-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0834-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0836-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0837-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0838-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0839-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0840-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0841-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0842-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0843-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0845-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0846-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0847-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0848-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0849-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0851-0001-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0851-0001-0002.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0851-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0852-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0853-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0854-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0855-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0856-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0857-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0858-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0859-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0860-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0862-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0863-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0865-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0866-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0867-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0868-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0869-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0870-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0871-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0872-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0873-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0874-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0875-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0876-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0877-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0879-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0880-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0881-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0882-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0885-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0886-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0887-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0888-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0890-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0892-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0893-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0894-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0895-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0896-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0897-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0898-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0899-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0900-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0903-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0904-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0905-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0906-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0907-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0908-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0909-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0910-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0911-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0912-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0913-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0914-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0915-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0917-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0918-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0919-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0922-0001.jpeg
#   inflating: tr/chest_xray/train/NORMAL/NORMAL2-IM-0923-0001.jpeg
# ...
#   inflating: tr/chest_xray/train/PNEUMONIA/person88_virus_161.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person88_virus_163.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person88_virus_164.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person88_virus_165.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person88_virus_166.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person88_virus_167.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person890_bacteria_2814.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person890_virus_1540.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person891_virus_1541.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person892_bacteria_2817.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person893_bacteria_2818.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person894_bacteria_2819.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person894_virus_1546.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person895_bacteria_2820.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person895_virus_1547.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person896_bacteria_2821.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person896_virus_1548.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person897_bacteria_2822.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person898_bacteria_2823.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person898_virus_1552.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person899_virus_1553.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person89_virus_168.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person8_bacteria_37.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person900_virus_1554.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person901_virus_1555.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person902_bacteria_2827.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person903_bacteria_2828.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person904_bacteria_2829.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person905_bacteria_2830.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person905_virus_1561.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person906_bacteria_2831.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person906_virus_1562.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person907_bacteria_2832.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person907_virus_1563.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person908_virus_1564.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person909_bacteria_2834.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person909_virus_1565.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person90_virus_169.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person90_virus_170.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person911_bacteria_2836.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person911_virus_1567.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person912_bacteria_2837.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person913_bacteria_2838.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person913_virus_1570.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person914_bacteria_2839.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person914_virus_1571.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person915_virus_1572.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person916_bacteria_2841.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person917_bacteria_2842.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person918_bacteria_2843.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person918_virus_1575.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person919_bacteria_2844.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person919_virus_1576.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person920_bacteria_2845.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person920_virus_1577.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person921_bacteria_2846.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person921_virus_1578.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person922_bacteria_2847.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person923_bacteria_2848.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person924_bacteria_2849.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person924_virus_1581.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person925_bacteria_2850.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person925_virus_1582.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person926_virus_1583.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person927_bacteria_2852.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person927_virus_1584.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person928_virus_1586.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person929_bacteria_2854.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person929_virus_1588.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person929_virus_1589.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person92_virus_174.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person930_bacteria_2855.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person931_bacteria_2856.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person931_virus_1592.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person932_virus_1593.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person933_bacteria_2858.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person933_virus_1594.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person934_bacteria_2859.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person934_virus_1595.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person935_virus_1597.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person936_bacteria_2861.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person936_virus_1598.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person937_bacteria_2862.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person937_virus_1599.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person938_bacteria_2863.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person938_virus_1600.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person939_bacteria_2864.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person93_virus_175.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person940_bacteria_2865.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person940_virus_1602.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person940_virus_1604.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person940_virus_1605.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person940_virus_1607.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person940_virus_1609.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person941_virus_1610.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person942_bacteria_2867.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person942_virus_1611.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person943_bacteria_2868.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person944_bacteria_2869.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person945_bacteria_2870.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person945_virus_1616.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person946_bacteria_2871.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person947_bacteria_2872.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person947_virus_1618.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person949_bacteria_2874.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person949_virus_1620.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person94_virus_176.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person950_virus_1621.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person951_bacteria_2876.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person951_virus_1622.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person952_bacteria_2877.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person952_virus_1623.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person953_bacteria_2878.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person954_bacteria_2879.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person954_virus_1626.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person955_bacteria_2880.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person955_virus_1627.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person956_bacteria_2881.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person956_virus_1628.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person957_bacteria_2882.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person958_bacteria_2883.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person958_virus_1630.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person959_bacteria_2884.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person95_virus_177.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person960_bacteria_2885.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person960_virus_1633.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person961_bacteria_2886.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person961_virus_1634.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person962_bacteria_2887.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person962_virus_1635.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person963_bacteria_2888.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person963_virus_1636.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person964_bacteria_2889.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person964_virus_1637.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person965_bacteria_2890.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person965_virus_1638.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person966_bacteria_2891.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person966_virus_1639.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person967_bacteria_2892.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person967_virus_1640.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person968_bacteria_2893.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person968_virus_1642.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person969_bacteria_2894.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person969_virus_1643.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person96_virus_178.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person96_virus_179.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person970_bacteria_2895.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person970_virus_1644.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person971_bacteria_2896.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person972_bacteria_2897.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person972_virus_1646.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person973_virus_1647.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person974_bacteria_2899.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person974_virus_1649.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person975_virus_1650.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person976_bacteria_2901.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person976_virus_1651.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person977_bacteria_2902.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person977_virus_1652.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person978_bacteria_2904.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person978_virus_1653.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person979_bacteria_2905.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person979_virus_1654.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person97_virus_180.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person97_virus_181.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person980_bacteria_2906.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person980_virus_1655.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person981_bacteria_2907.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person981_bacteria_2908.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person981_virus_1657.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person982_bacteria_2909.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person982_virus_1658.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person983_bacteria_2910.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person983_virus_1660.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person984_bacteria_2911.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person985_bacteria_2912.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person986_bacteria_2913.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person987_bacteria_2914.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person988_bacteria_2915.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person988_virus_1666.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person989_virus_1667.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person98_virus_182.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person990_bacteria_2917.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person991_bacteria_2918.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person991_virus_1669.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person992_bacteria_2919.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person992_bacteria_2920.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person992_virus_1670.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person993_bacteria_2921.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person993_virus_1671.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person994_bacteria_2922.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person994_virus_1672.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person995_bacteria_2923.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person995_virus_1676.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person996_bacteria_2924.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person996_virus_1677.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person997_bacteria_2926.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person997_virus_1678.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person998_bacteria_2927.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person998_bacteria_2928.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person99_virus_183.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person9_bacteria_38.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person9_bacteria_39.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person9_bacteria_40.jpeg
#   inflating: tr/chest_xray/train/PNEUMONIA/person9_bacteria_41.jpeg
#   inflating: tr/chest_xray/val/NORMAL/NORMAL2-IM-1427-0001.jpeg
#   inflating: tr/chest_xray/val/NORMAL/NORMAL2-IM-1430-0001.jpeg
#   inflating: tr/chest_xray/val/NORMAL/NORMAL2-IM-1431-0001.jpeg
#   inflating: tr/chest_xray/val/NORMAL/NORMAL2-IM-1436-0001.jpeg
#   inflating: tr/chest_xray/val/NORMAL/NORMAL2-IM-1437-0001.jpeg
#   inflating: tr/chest_xray/val/NORMAL/NORMAL2-IM-1438-0001.jpeg
#   inflating: tr/chest_xray/val/NORMAL/NORMAL2-IM-1440-0001.jpeg
#   inflating: tr/chest_xray/val/NORMAL/NORMAL2-IM-1442-0001.jpeg
#   inflating: tr/chest_xray/val/PNEUMONIA/person1946_bacteria_4874.jpeg
#   inflating: tr/chest_xray/val/PNEUMONIA/person1946_bacteria_4875.jpeg
#   inflating: tr/chest_xray/val/PNEUMONIA/person1947_bacteria_4876.jpeg
#   inflating: tr/chest_xray/val/PNEUMONIA/person1949_bacteria_4880.jpeg
#   inflating: tr/chest_xray/val/PNEUMONIA/person1950_bacteria_4881.jpeg
#   inflating: tr/chest_xray/val/PNEUMONIA/person1951_bacteria_4882.jpeg
#   inflating: tr/chest_xray/val/PNEUMONIA/person1952_bacteria_4883.jpeg
#   inflating: tr/chest_xray/val/PNEUMONIA/person1954_bacteria_4886.jpeg

# %% [markdown]
# The Dataset I use from URL : https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia
#
# Data set contains = 5,863 X-Ray images (JPEG) and 2 categories (Pneumonia/Normal).
# * Train set =
# * Test =
# * Validation =

# %%
#Importing the necessary libraries

import numpy as np  # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import random

import keras
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

import cv2
import os

# %%
# Loadin and sorting the test, train and val so we can know how much Xray values we have in each one of the folders
IMG_SIZE =  100

labels = ['NORMAL','PNEUMONIA']
def get_training_data(library_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(library_dir, label)#Allows us to access subfolders of test,train,val
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)#read the xray and convert it to gray scale
                resized_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE)) # Reshaping images size
                data.append([resized_arr, class_num])
            except Exception as e:
                #print(e)
                pass
    return np.array(data)

#Loading the Dataset       
test = get_training_data('/content/tr/chest_xray/test')
train = get_training_data('/content/tr/chest_xray/train')
val = get_training_data('/content/tr/chest_xray/val') 


print('size of test set :',len(test))
print('size of train set :',len(train))
print('size of validation set :',len(val))
print("Dataset Test       : {0} ({1:0.2f}%)".format(len(test), (len(test)/(len(test)+len(train)+len(val))) * 100.0))
print("Dataset Train      : {0} ({1:0.2f}%)".format(len(train), (len(train)/(len(test)+len(train)+len(val))) * 100.0))
print("Dataset Validation : {0} ({1:0.2f}%)".format(len(val), (len(val)/(len(test)+len(train)+len(val))) * 100.0))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# size of test set : 624
# size of train set : 5216
# size of validation set : 16
# Dataset Test       : 624 (10.66%)
# Dataset Train      : 5216 (89.07%)
# Dataset Validation : 16 (0.27%)

# %%
l = []
pneumonia_count = 0
normal_count = 0

for i in train:
    if(i[1] == 1):
        l.append("Pneunomia")
        pneumonia_count = pneumonia_count + 1
    else:
        l.append("Normal")
        normal_count = normal_count + 1

sns.set_style('darkgrid')
sns.countplot(l)  

print(' \ntrain_set:\n')
print('Pneumonia cases :',pneumonia_count)
print('Normals   cases :',normal_count)
print('')

pneumonia_count = 0
normal_count = 0

for i in val:
    if(i[1] == 1):
        pneumonia_count = pneumonia_count + 1
    else:
        normal_count = normal_count + 1

print(' \nvalidation_set:\n')
print('Pneumonia cases :',pneumonia_count)
print('Normals   cases :',normal_count)
print('\n')

plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])

 #The training data seems imbalanced .
   # To increase the no. of training examples, we will use data augmentation
# Out:
#
# train_set:
#
# Pneumonia cases : 3875
# Normals   cases : 1341
#
#
# validation_set:
#
# Pneumonia cases : 8
# Normals   cases : 8
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'PNEUMONIA')

# %% [markdown]
# From the result above We got from training data:
# Pneumonia cases : 3875
# Normals   cases : 1341

# %%
#The training data seems imbalanced .
# To increase the no. of training examples, we will use data augmentation

# Store each {data,label} in 2 different lists
x_train = []
y_train = [] 

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# resize data for deep learning 
x_train = x_train.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y_test = np.array(y_test)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 35,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.3, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
#build the model (CNN)
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (IMG_SIZE,IMG_SIZE,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))


model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))


model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
#define callbacks
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
#fit the training data to the model
EPOCHS = 12
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = EPOCHS , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])

print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 32)      320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100, 100, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 13, 13, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               131200
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 567,649
# Trainable params: 566,497
# Non-trainable params: 1,152
# _________________________________________________________________
# Epoch 1/12
# 163/163 [==============================] - 102s 611ms/step - loss: 0.6482 - accuracy: 0.8019 - val_loss: 13.2682 - val_accuracy: 0.5000
# Epoch 2/12
# 163/163 [==============================] - 100s 611ms/step - loss: 0.2947 - accuracy: 0.8812 - val_loss: 18.0258 - val_accuracy: 0.5000
# Epoch 3/12
# 163/163 [==============================] - 99s 608ms/step - loss: 0.2361 - accuracy: 0.9095 - val_loss: 18.9822 - val_accuracy: 0.5000
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 4/12
# 163/163 [==============================] - 99s 610ms/step - loss: 0.1586 - accuracy: 0.9396 - val_loss: 7.5150 - val_accuracy: 0.5000
# Epoch 5/12
# 163/163 [==============================] - 100s 616ms/step - loss: 0.1543 - accuracy: 0.9427 - val_loss: 3.2254 - val_accuracy: 0.5000
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 6/12
# 163/163 [==============================] - 100s 611ms/step - loss: 0.1257 - accuracy: 0.9538 - val_loss: 0.3813 - val_accuracy: 0.8750
# Epoch 7/12
# 163/163 [==============================] - 100s 616ms/step - loss: 0.1293 - accuracy: 0.9510 - val_loss: 2.4584 - val_accuracy: 0.5625
# Epoch 8/12
# 163/163 [==============================] - 101s 616ms/step - loss: 0.1194 - accuracy: 0.9547 - val_loss: 3.8885 - val_accuracy: 0.5000
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 9/12
# 163/163 [==============================] - 100s 613ms/step - loss: 0.1186 - accuracy: 0.9566 - val_loss: 0.8266 - val_accuracy: 0.6875
# Epoch 10/12
# 163/163 [==============================] - 100s 612ms/step - loss: 0.1079 - accuracy: 0.9634 - val_loss: 0.3915 - val_accuracy: 0.8750
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 11/12
# 163/163 [==============================] - 101s 617ms/step - loss: 0.1178 - accuracy: 0.9547 - val_loss: 1.3090 - val_accuracy: 0.5000
# Epoch 12/12
# 163/163 [==============================] - 100s 616ms/step - loss: 0.1051 - accuracy: 0.9634 - val_loss: 1.4110 - val_accuracy: 0.5625
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 20/20 [==============================] - 3s 129ms/step - loss: 0.3272 - accuracy: 0.9038
# Loss of the model is -  0.32724475860595703
# 20/20 [==============================] - 3s 129ms/step - loss: 0.3272 - accuracy: 0.9038
# Accuracy of the model is -  90.38461446762085 %

# %%
#-------------------------------Analysis after Model Training-------------------------------#
def show_predection_examples(pred_class,pred_prob,nb_examples):

    fig = plt.figure(figsize=(10, 10))

    rand_index = 0
    prob = 0
    for i in range(nb_examples):

        rand_index = random.randint(0,len(pred_class))
        plt.subplot(3,2,i+1)

        # label 0 is 'Pneunomia' ,label 0 is 'Normal'     
        img_label = int(pred_class[rand_index])  

        prob = np.round(pred_prob[rand_index],3)     #(float) probabilty that the image label is 'Pneunomia'

        if img_label == 1:
            pass       
        else:
             prob = np.round(1 - prob,3)             #(float) probabilty that the image label is 'Normal' 
             # prediction probabilty will be a float number close to 0 , we might understand its definition if we 
             # compute the complement to 1 ; prob(Normal) = 1 - sigmoid_probability_evalutaion , this is only needed 
             # when we need to show the prediction probability of nb_examples images...

        plt.xticks([])
        plt.yticks([])
        plt.imshow(x_test[rand_index].reshape(IMG_SIZE,IMG_SIZE), cmap="gray", interpolation='none')
        plt.title("Predicted Class {},Actual Class {}".format(pred_class[rand_index], y_test[rand_index]))
        plt.xlabel(labels[img_label]+': '+str(prob))
        plt.subplots_adjust(bottom=0.5, wspace=0.5, hspace=0.5)

    plt.tight_layout()

# %%
###Definitions
# Define 1:  train & validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']

## Define 2: train & validation AUC
train_auc_name = list(history.history.keys())[3]
val_auc_name = list(history.history.keys())[1]
train_auc = history.history[train_auc_name]
val_auc = history.history[val_auc_name]

## Define 3: y_pred & y_true : y_test
prediction_probability = model.predict(x_test)
prediction_class= model.predict_classes(x_test)
y_pred = (prediction_class > 0.5).T[0]
y_pred_prob = prediction_probability.T[0]

show_predection_examples(prediction_class,prediction_probability,4)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#-----------------------------------Building Plots-----------------------------------#

fig = plt.figure(figsize=(10, 10))

# PLOT 1: TRAIN VS. VALIDATION LOSS 
plt.subplot(2,2,1)
plt.title("Training vs. Validation Loss")
plt.plot(train_loss, label='training loss')
plt.plot(val_loss, label='validation loss')
plt.xlabel("Number of Epochs", size = EPOCHS)
plt.legend()

# %%
# PLOT 2: CONFUSION MATRIX
fig = plt.figure(figsize=(14, 10))
plt.subplot(2,2,3)

    # Set up the labels for in the confusion matrix
cm = confusion_matrix(y_test, y_pred)
names = ['TP', 'FN', 'FP', 'TN']
counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
labels = np.asarray(labels).reshape(2,2)
ticklabels = ['Pneumonia','Normal']

    # Create confusion matrix as heatmap
sns.set(font_scale = 1.4)
ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels=ticklabels, yticklabels=ticklabels )
plt.xticks(size=EPOCHS)
plt.yticks(size=EPOCHS)
plt.title("Confusion Matrix")
plt.xlabel("Predicted", size= EPOCHS)
plt.ylabel("Actual", size= EPOCHS)
# Out:
# Text(97.5, 0.5, 'Actual')

# %%
# PLOT 3: TRAIN VS. VALIDATION AUC
fig = plt.figure(figsize=(16, 10))
plt.subplot(2,2,2)
plt.title("Training vs. Validation Accuracy")
plt.plot(train_auc, label='training acc.')
plt.plot(val_auc, label='validation acc.')
plt.xlabel("Number of Epochs", size = EPOCHS)
plt.legend()

# %%
# PLOT 4: ROC CURVE
fig = plt.figure(figsize=(14, 10))
plt.subplot(2,2,4)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
auc = roc_auc_score(y_test, y_pred_prob)
plt.title('ROC Curve')
plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
plt.xlabel('False Positive Rate', size = EPOCHS)
plt.ylabel('True Positive Rate', size = EPOCHS)
plt.legend(loc='best')

# END PLOTS
plt.tight_layout()

# Summary Statistics

    #Accuracy : 1 - (Average Classification Error) = (TP + TN) / (TP + FN + TN + FP)  --> % positive out of all predicted positives
    #Precision : how many selected items are relevant = TP / (TP + FP)                --> % positive out of all predicted positives
    #Recall : how many relevant items are selected = TP / (TP + FN)                   --> % positive out of all supposed to be positives
    #Specifity :                                                                      --> % negative out of all supposed to be negatives
    #F1-score : harmonic mean between Precision and Recall = (2*precision * recall) / (precision + recall)

#cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
TN, FP, FN, TP = cm.ravel()         
accuracy = (TP + TN) / np.sum(cm)   
precision = TP / (TP+FP)            
recall =  TP / (TP+FN)              
specifity = TN / (TN+FP)           
f1 = 2 * precision * recall / (precision + recall)
stats_summary = '[Classification Metrics Summary]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specifity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specifity, f1)
print(stats_summary)
# Out:
# [Classification Metrics Summary]
# Accuracy = 90.38% | Precision = 89.29% | Recall = 96.15% | Specifity = 80.77% | F1 Score = 92.59%

# %%
#build the model (CNN - 2)
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (IMG_SIZE,IMG_SIZE,1)))
model.add(BatchNormalization())
model.add(MaxPool2aD((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))


model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))


model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 100, 100, 32)      320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 100, 100, 32)      128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 13, 13, 64)        256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 128)         73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 7, 128)         512
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 567,649
# Trainable params: 566,497
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
##Set Hyperparameter Learning Rate 0,03
#define callbacks
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.03)
#fit the training data to the model
EPOCHS = 30
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = EPOCHS , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])

print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# Epoch 1/30
# 163/163 [==============================] - 105s 631ms/step - loss: 0.6310 - accuracy: 0.8013 - val_loss: 16.2557 - val_accuracy: 0.5000
# Epoch 2/30
# 163/163 [==============================] - 101s 621ms/step - loss: 0.2804 - accuracy: 0.8837 - val_loss: 17.8287 - val_accuracy: 0.5000
# Epoch 3/30
# 163/163 [==============================] - 100s 611ms/step - loss: 0.2557 - accuracy: 0.9018 - val_loss: 24.0637 - val_accuracy: 0.5000
# Epoch 4/30
# 163/163 [==============================] - 101s 621ms/step - loss: 0.2077 - accuracy: 0.9176 - val_loss: 4.6474 - val_accuracy: 0.5000
# Epoch 5/30
# 163/163 [==============================] - 104s 635ms/step - loss: 0.2121 - accuracy: 0.9304 - val_loss: 2.7103 - val_accuracy: 0.5625
# Epoch 6/30
# 163/163 [==============================] - 102s 627ms/step - loss: 0.1820 - accuracy: 0.9308 - val_loss: 8.1573 - val_accuracy: 0.5000
# Epoch 7/30
# 163/163 [==============================] - 101s 620ms/step - loss: 0.1617 - accuracy: 0.9381 - val_loss: 1.9939 - val_accuracy: 0.5000
# Epoch 8/30
# 163/163 [==============================] - 100s 613ms/step - loss: 0.1772 - accuracy: 0.9362 - val_loss: 3.7307 - val_accuracy: 0.6250
# Epoch 9/30
# 163/163 [==============================] - 100s 614ms/step - loss: 0.1704 - accuracy: 0.9356 - val_loss: 1.2790 - val_accuracy: 0.7500
# Epoch 10/30
# 163/163 [==============================] - 100s 615ms/step - loss: 0.1504 - accuracy: 0.9460 - val_loss: 1.3005 - val_accuracy: 0.5625
# Epoch 11/30
# 163/163 [==============================] - 102s 626ms/step - loss: 0.1274 - accuracy: 0.9527 - val_loss: 1.1050 - val_accuracy: 0.5625
# Epoch 12/30
# 163/163 [==============================] - 101s 620ms/step - loss: 0.1813 - accuracy: 0.9417 - val_loss: 2.2999 - val_accuracy: 0.5625
# Epoch 13/30
# 163/163 [==============================] - 100s 615ms/step - loss: 0.1433 - accuracy: 0.9460 - val_loss: 2.4720 - val_accuracy: 0.5625
# Epoch 14/30
# 163/163 [==============================] - 102s 626ms/step - loss: 0.1586 - accuracy: 0.9461 - val_loss: 5.1322 - val_accuracy: 0.5000
# Epoch 15/30
# 163/163 [==============================] - 101s 621ms/step - loss: 0.1344 - accuracy: 0.9534 - val_loss: 24.7105 - val_accuracy: 0.5000
# Epoch 16/30
# 163/163 [==============================] - 100s 614ms/step - loss: 0.1400 - accuracy: 0.9463 - val_loss: 50.7834 - val_accuracy: 0.5000
# Epoch 17/30
# 163/163 [==============================] - 102s 625ms/step - loss: 0.1466 - accuracy: 0.9500 - val_loss: 1.4922 - val_accuracy: 0.6875
# Epoch 18/30
# 163/163 [==============================] - 100s 615ms/step - loss: 0.1398 - accuracy: 0.9513 - val_loss: 16.5505 - val_accuracy: 0.5000
# Epoch 19/30
# 163/163 [==============================] - 101s 619ms/step - loss: 0.1297 - accuracy: 0.9513 - val_loss: 2.0522 - val_accuracy: 0.6875
# Epoch 20/30
# 163/163 [==============================] - 100s 616ms/step - loss: 0.1162 - accuracy: 0.9510 - val_loss: 2.9369 - val_accuracy: 0.5000
# Epoch 21/30
# 163/163 [==============================] - 100s 612ms/step - loss: 0.1201 - accuracy: 0.9574 - val_loss: 17.6841 - val_accuracy: 0.5000
# Epoch 22/30
# 163/163 [==============================] - 101s 619ms/step - loss: 0.1104 - accuracy: 0.9568 - val_loss: 0.8155 - val_accuracy: 0.6875
# Epoch 23/30
# 163/163 [==============================] - 102s 626ms/step - loss: 0.1081 - accuracy: 0.9574 - val_loss: 10.3127 - val_accuracy: 0.5000
# Epoch 24/30
# 163/163 [==============================] - 101s 617ms/step - loss: 0.1092 - accuracy: 0.9588 - val_loss: 2.9302 - val_accuracy: 0.5625
# Epoch 25/30
# 163/163 [==============================] - 101s 617ms/step - loss: 0.1226 - accuracy: 0.9559 - val_loss: 2.4725 - val_accuracy: 0.5625
# Epoch 26/30
# 163/163 [==============================] - 101s 622ms/step - loss: 0.1184 - accuracy: 0.9543 - val_loss: 1.3132 - val_accuracy: 0.5625
# Epoch 27/30
# 163/163 [==============================] - 102s 627ms/step - loss: 0.1039 - accuracy: 0.9586 - val_loss: 2.7672 - val_accuracy: 0.5625
# Epoch 28/30
# 163/163 [==============================] - 103s 631ms/step - loss: 0.1125 - accuracy: 0.9627 - val_loss: 1.6434 - val_accuracy: 0.6875
# Epoch 29/30
# 163/163 [==============================] - 102s 626ms/step - loss: 0.1104 - accuracy: 0.9601 - val_loss: 0.4707 - val_accuracy: 0.8750
# Epoch 30/30
# 163/163 [==============================] - 101s 622ms/step - loss: 0.1109 - accuracy: 0.9568 - val_loss: 2.3638 - val_accuracy: 0.5625
# 20/20 [==============================] - 3s 133ms/step - loss: 0.3917 - accuracy: 0.9022
# Loss of the model is -  0.3916757106781006
# 20/20 [==============================] - 3s 134ms/step - loss: 0.3917 - accuracy: 0.9022
# Accuracy of the model is -  90.22436141967773 %

# %%
#### Analysis after Model Training 1
#-------------------------------Analysis after Model Training-------------------------------#
def show_predection_examples(pred_class,pred_prob,nb_examples):

    fig = plt.figure(figsize=(10, 10))

    rand_index = 0
    prob = 0
    for i in range(nb_examples):

        rand_index = random.randint(0,len(pred_class))
        plt.subplot(3,2,i+1)

        # label 0 is 'Pneunomia' ,label 0 is 'Normal'     
        img_label = int(pred_class[rand_index])  

        prob = np.round(pred_prob[rand_index],3)     #(float) probabilty that the image label is 'Pneunomia'

        if img_label == 1:
            pass       
        else:
             prob = np.round(1 - prob,3)             #(float) probabilty that the image label is 'Normal' 
             # prediction probabilty will be a float number close to 0 , we might understand its definition if we 
             # compute the complement to 1 ; prob(Normal) = 1 - sigmoid_probability_evalutaion , this is only needed 
             # when we need to show the prediction probability of nb_examples images...

        plt.xticks([])
        plt.yticks([])
        plt.imshow(x_test[rand_index].reshape(IMG_SIZE,IMG_SIZE), cmap="gray", interpolation='none')
        plt.title("Predicted Class {},Actual Class {}".format(pred_class[rand_index], y_test[rand_index]))
        plt.xlabel(labels[img_label]+': '+str(prob))
        plt.subplots_adjust(bottom=0.5, wspace=0.5, hspace=0.5)

    plt.tight_layout()

# %%
#-----------------------------------Global Definitions-----------------------------------#

# Define 1:  train & validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']

## Define 2: train & validation AUC
train_auc_name = list(history.history.keys())[3]
val_auc_name = list(history.history.keys())[1]
train_auc = history.history[train_auc_name]
val_auc = history.history[val_auc_name]

## Define 3: y_pred & y_true : y_test
prediction_probability1 = model.predict(x_test)
prediction_class1= model.predict_classes(x_test)
y_pred = (prediction_class > 0.5).T[0]
y_pred_prob = prediction_probability.T[0]

show_predection_examples(prediction_class1,prediction_probability1,4)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-55-3d2686ebc340> in <module>()
#      17 y_pred_prob = prediction_probability.T[0]
#      18
# ---> 19 show_predection_examples(prediction_class1,prediction_probability1,4)
#
# <ipython-input-49-d496c4d1a61c> in show_predection_examples(pred_class, pred_prob, nb_examples)
#      29         plt.imshow(x_test[rand_index].reshape(IMG_SIZE,IMG_SIZE), cmap="gray", interpolation='none')
#      30         plt.title("Predicted Class {},Actual Class {}".format(pred_class[rand_index], y_test[rand_index]))
# ---> 31         plt.xlabel(labels[img_label]+': '+str(prob))
#      32         plt.subplots_adjust(bottom=0.5, wspace=0.5, hspace=0.5)
#      33
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U9'), dtype('<U9')) -> dtype('<U9')

# %%
#Building Plots#
fig = plt.figure(figsize=(16, 10))

# PLOT 1: TRAIN VS. VALIDATION LOSS epoch 30
plt.subplot(2,2,1)
plt.title("Training vs. Validation Loss")
plt.plot(train_loss, label='training loss')
plt.plot(val_loss, label='validation loss')
plt.xlabel("Number of Epochs", size = EPOCHS)
plt.legend()

# %%
# PLOT 2: CONFUSION MATRIX
fig = plt.figure(figsize=(14, 10))
plt.subplot(2,2,3)

    # Set up the labels for in the confusion matrix
cm = confusion_matrix(y_test, y_pred)
names = ['TP', 'FN', 'FP', 'TN']
counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
labels = np.asarray(labels).reshape(2,2)
ticklabels = ['Pneumonia','Normal']

    # Create confusion matrix as heatmap
sns.set(font_scale = 1.4)
ax = sns.heatmap(cm, annot=labels, fmt='', cmap='viridis', xticklabels=ticklabels, yticklabels=ticklabels )
plt.xticks(size=EPOCHS)
plt.yticks(size=EPOCHS)
plt.title("Confusion Matrix")
plt.xlabel("Predicted", size= EPOCHS)
plt.ylabel("Actual", size= EPOCHS)
# Out:
# Text(97.5, 0.5, 'Actual')

# %%
# PLOT 3: TRAIN VS. VALIDATION AUC
fig = plt.figure(figsize=(16, 10))
plt.subplot(2,2,2)
plt.title("Training vs. Validation Accuracy")
plt.plot(train_auc, label='training acc.')
plt.plot(val_auc, label='validation acc.')
plt.xlabel("Number of Epochs", size = EPOCHS)
plt.legend()

# %%
# PLOT 4: ROC CURVE
fig = plt.figure(figsize=(14, 10))
plt.subplot(2,2,4)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
auc = roc_auc_score(y_test, y_pred_prob)
plt.title('ROC Curve')
plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
plt.xlabel('False Positive Rate', size = EPOCHS)
plt.ylabel('True Positive Rate', size = EPOCHS)
plt.legend(loc='best')

# END PLOTS
plt.tight_layout()

# Summary Statistics

    #Accuracy : 1 - (Average Classification Error) = (TP + TN) / (TP + FN + TN + FP)  --> % positive out of all predicted positives
    #Precision : how many selected items are relevant = TP / (TP + FP)                --> % positive out of all predicted positives
    #Recall : how many relevant items are selected = TP / (TP + FN)                   --> % positive out of all supposed to be positives
    #Specifity :                                                                      --> % negative out of all supposed to be negatives
    #F1-score : harmonic mean between Precision and Recall = (2*precision * recall) / (precision + recall)

#cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
TN, FP, FN, TP = cm.ravel()         
accuracy = (TP + TN) / np.sum(cm)   
precision = TP / (TP+FP)            
recall =  TP / (TP+FN)              
specifity = TN / (TN+FP)           
f1 = 2 * precision * recall / (precision + recall)
stats_summary = '[Classification Metrics Summary]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specifity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specifity, f1)
print(stats_summary)
# Out:
# [Classification Metrics Summary]
# Accuracy = 90.22% | Precision = 88.71% | Recall = 96.67% | Specifity = 79.49% | F1 Score = 92.52%

# %%
#build the model (CNN - 3)
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization

model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (IMG_SIZE,IMG_SIZE,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))


model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))


model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model.add(Flatten())
model.add(Dense(units = 256 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 100, 100, 32)      320
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 100, 100, 32)      128
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 50, 50, 64)        256
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 25, 25, 64)        36928
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 7, 7, 256)         295168
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 7, 7, 256)         1024
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 1,280,705
# Trainable params: 1,279,105
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
##Set Hyperparameter Learning Rate 0,5
#define callbacks
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.5)
#fit the training data to the model
EPOCHS = 50
history = model.fit(datagen.flow(x_train,y_train, batch_size = 64) ,epochs = EPOCHS , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])

print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# Epoch 1/50
# 82/82 [==============================] - 157s 2s/step - loss: 1.0357 - accuracy: 0.7795 - val_loss: 6.5317 - val_accuracy: 0.5000
# Epoch 2/50
# 82/82 [==============================] - 151s 2s/step - loss: 0.2949 - accuracy: 0.8729 - val_loss: 11.0365 - val_accuracy: 0.5000
# Epoch 3/50
# 82/82 [==============================] - 149s 2s/step - loss: 0.2424 - accuracy: 0.8992 - val_loss: 15.4968 - val_accuracy: 0.5000
# Epoch 4/50
# 82/82 [==============================] - 149s 2s/step - loss: 0.2099 - accuracy: 0.9202 - val_loss: 14.4257 - val_accuracy: 0.5000
# Epoch 5/50
# 82/82 [==============================] - 147s 2s/step - loss: 0.1894 - accuracy: 0.9275 - val_loss: 11.2905 - val_accuracy: 0.5000
# Epoch 6/50
# 82/82 [==============================] - 148s 2s/step - loss: 0.1685 - accuracy: 0.9374 - val_loss: 33.2604 - val_accuracy: 0.5000
# Epoch 7/50
# 82/82 [==============================] - 151s 2s/step - loss: 0.1738 - accuracy: 0.9310 - val_loss: 12.7503 - val_accuracy: 0.5000
# Epoch 8/50
# 82/82 [==============================] - 148s 2s/step - loss: 0.1683 - accuracy: 0.9375 - val_loss: 0.8523 - val_accuracy: 0.6250
# Epoch 9/50
# 82/82 [==============================] - 147s 2s/step - loss: 0.1573 - accuracy: 0.9424 - val_loss: 1.8810 - val_accuracy: 0.5625
# Epoch 10/50
# 82/82 [==============================] - 149s 2s/step - loss: 0.1453 - accuracy: 0.9451 - val_loss: 0.7577 - val_accuracy: 0.5625
# Epoch 11/50
# 82/82 [==============================] - 148s 2s/step - loss: 0.1351 - accuracy: 0.9480 - val_loss: 3.0270 - val_accuracy: 0.5625
# Epoch 12/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.1417 - accuracy: 0.9494 - val_loss: 11.1338 - val_accuracy: 0.5000
# Epoch 13/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.1363 - accuracy: 0.9522 - val_loss: 1.3409 - val_accuracy: 0.5625
# Epoch 14/50
# 82/82 [==============================] - 144s 2s/step - loss: 0.1229 - accuracy: 0.9540 - val_loss: 2.9310 - val_accuracy: 0.5625
# Epoch 15/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.1394 - accuracy: 0.9482 - val_loss: 0.7016 - val_accuracy: 0.6875
# Epoch 16/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.1165 - accuracy: 0.9588 - val_loss: 0.8858 - val_accuracy: 0.6875
# Epoch 17/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.1220 - accuracy: 0.9518 - val_loss: 2.1332 - val_accuracy: 0.5625
# Epoch 18/50
# 82/82 [==============================] - 144s 2s/step - loss: 0.1277 - accuracy: 0.9531 - val_loss: 1.2787 - val_accuracy: 0.7500
# Epoch 19/50
# 82/82 [==============================] - 146s 2s/step - loss: 0.1212 - accuracy: 0.9563 - val_loss: 2.5206 - val_accuracy: 0.5625
# Epoch 20/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.1051 - accuracy: 0.9623 - val_loss: 15.1112 - val_accuracy: 0.5000
# Epoch 21/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.1174 - accuracy: 0.9586 - val_loss: 0.4260 - val_accuracy: 0.8125
# Epoch 22/50
# 82/82 [==============================] - 146s 2s/step - loss: 0.1021 - accuracy: 0.9634 - val_loss: 2.6814 - val_accuracy: 0.4375
# Epoch 23/50
# 82/82 [==============================] - 144s 2s/step - loss: 0.1119 - accuracy: 0.9628 - val_loss: 2.1495 - val_accuracy: 0.5625
# Epoch 24/50
# 82/82 [==============================] - 144s 2s/step - loss: 0.1119 - accuracy: 0.9657 - val_loss: 3.8654 - val_accuracy: 0.5625
# Epoch 25/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.0903 - accuracy: 0.9687 - val_loss: 0.7546 - val_accuracy: 0.7500
# Epoch 26/50
# 82/82 [==============================] - 148s 2s/step - loss: 0.1153 - accuracy: 0.9612 - val_loss: 58.4043 - val_accuracy: 0.5000
# Epoch 27/50
# 82/82 [==============================] - 144s 2s/step - loss: 0.1050 - accuracy: 0.9611 - val_loss: 1.1103 - val_accuracy: 0.6875
# Epoch 28/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.0999 - accuracy: 0.9644 - val_loss: 10.9165 - val_accuracy: 0.5000
# Epoch 29/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.1067 - accuracy: 0.9585 - val_loss: 1.3789 - val_accuracy: 0.6875
# Epoch 30/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.0967 - accuracy: 0.9627 - val_loss: 3.7011 - val_accuracy: 0.5000
# Epoch 31/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.1025 - accuracy: 0.9664 - val_loss: 0.4049 - val_accuracy: 0.8750
# Epoch 32/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.0951 - accuracy: 0.9637 - val_loss: 1.8432 - val_accuracy: 0.5000
# Epoch 33/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.0955 - accuracy: 0.9672 - val_loss: 0.9159 - val_accuracy: 0.7500
# Epoch 34/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.0841 - accuracy: 0.9684 - val_loss: 4.7560 - val_accuracy: 0.5000
# Epoch 35/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.1024 - accuracy: 0.9640 - val_loss: 0.7441 - val_accuracy: 0.6875
# Epoch 36/50
# 82/82 [==============================] - 150s 2s/step - loss: 0.1051 - accuracy: 0.9653 - val_loss: 1.4887 - val_accuracy: 0.5000
# Epoch 37/50
# 82/82 [==============================] - 146s 2s/step - loss: 0.0885 - accuracy: 0.9671 - val_loss: 20.2788 - val_accuracy: 0.5000
# Epoch 38/50
# 82/82 [==============================] - 147s 2s/step - loss: 0.0798 - accuracy: 0.9726 - val_loss: 0.7277 - val_accuracy: 0.8125
# Epoch 39/50
# 82/82 [==============================] - 148s 2s/step - loss: 0.0858 - accuracy: 0.9691 - val_loss: 1.0057 - val_accuracy: 0.8125
# Epoch 40/50
# 82/82 [==============================] - 146s 2s/step - loss: 0.0963 - accuracy: 0.9635 - val_loss: 0.4014 - val_accuracy: 0.8125
# Epoch 41/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.1037 - accuracy: 0.9625 - val_loss: 24.7173 - val_accuracy: 0.5000
# Epoch 42/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.0861 - accuracy: 0.9657 - val_loss: 2.3077 - val_accuracy: 0.5000
# Epoch 43/50
# 82/82 [==============================] - 144s 2s/step - loss: 0.0701 - accuracy: 0.9718 - val_loss: 12.8664 - val_accuracy: 0.5000
# Epoch 44/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.0835 - accuracy: 0.9689 - val_loss: 8.7396 - val_accuracy: 0.5000
# Epoch 45/50
# 82/82 [==============================] - 144s 2s/step - loss: 0.0774 - accuracy: 0.9747 - val_loss: 1.2276 - val_accuracy: 0.6250
# Epoch 46/50
# 82/82 [==============================] - 147s 2s/step - loss: 0.0845 - accuracy: 0.9712 - val_loss: 4.1643 - val_accuracy: 0.5000
# Epoch 47/50
# 82/82 [==============================] - 145s 2s/step - loss: 0.0736 - accuracy: 0.9743 - val_loss: 2.8340 - val_accuracy: 0.5000
# Epoch 48/50
# 82/82 [==============================] - 146s 2s/step - loss: 0.0763 - accuracy: 0.9749 - val_loss: 1.7148 - val_accuracy: 0.5625
# Epoch 49/50
# 82/82 [==============================] - 144s 2s/step - loss: 0.0799 - accuracy: 0.9695 - val_loss: 1.2143 - val_accuracy: 0.6875
# Epoch 50/50
# 82/82 [==============================] - 143s 2s/step - loss: 0.0784 - accuracy: 0.9740 - val_loss: 0.1393 - val_accuracy: 0.9375
# 20/20 [==============================] - 5s 231ms/step - loss: 0.4679 - accuracy: 0.8894
# Loss of the model is -  0.4679250121116638
# 20/20 [==============================] - 4s 198ms/step - loss: 0.4679 - accuracy: 0.8894
# Accuracy of the model is -  88.94230723381042 %
